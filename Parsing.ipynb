# %% [markdown]
# # HN classification Demo

# %%
import os
import json
import requests
import pandas as pd

# %% [markdown]
# ## Fetch Data

# %%
stories = []
base_url =  'https://hacker-news.firebaseio.com/v0/item/{}.json?print=pretty'
top_story_ids = eval(requests.get('https://hacker-news.firebaseio.com/v0/topstories.json').text)
data = [json.loads(requests.get(base_url.format(story)).text) for story in top_story_ids]

# %% [markdown]
# First we'll start with naive classification, just giving it a list of words to exclude. I didn't put much work into it, so the [results aren't great](https://en.wikipedia.org/wiki/Garbage_in,_garbage_out). But with more effort this method might still be a strong contender.

# %%
url_words = ['//github', '//wikipedia']
title_words = ['linux', 'hardware']

for d in data:
    if d['type'] == 'story':
        if 'text' not in d.keys():
            if all([w not in d['url'] for w in url_words]):
                if all([w not in d['url'] for w in url_words]):
                    if all([w not in d['title'] for w in title_words]):
                        print(d['title'] + '\n' + d['url'])
# Out:
# Planet Moons
# https://www.go-astronomy.com/planets/planet-moons.htm
# The German Tank Problem
# https://www.eadan.net/blog/german-tank-problem/
# Why factoring may be easier than you think
# http://math.mit.edu/~cohn/Thoughts/factoring.html
# Graphs and Geometry [pdf]
# http://web.cs.elte.hu/~lovasz/bookxx/geomgraphbook/geombook2019.01.11.pdf
# The Cost of JavaScript in 2019
# https://v8.dev/blog/cost-of-javascript-2019
# Open Letter to the Wikimedia Foundation Board of Trustees
# https://en.wikipedia.org/wiki/Wikipedia:Arbitration_Committee/Noticeboard#Open_letter_to_the_WMF_Board
# China pressured London police to arrest Tiananmen protester, says watchdog
# https://www.theguardian.com/world/2019/jun/30/political-pressure-before-arrest-of-chinese-dissident-london
# Vintage video game cartridges with built-in modems
# https://writing.markchristian.org/2019/06/29/communicating-cartridges/
# Live coding a vi for CP/M from scratch
# http://cowlark.com/2019-06-28-cpm-vi/
# The Energy Cost of Electric and Human-Powered Bicycles (2004) [pdf]
# https://www.ebikes.ca/documents/Ebike_Energy.pdf
# New home page makes it seem like Stack Overflow doesn't allow free use any more
# https://meta.stackoverflow.com/q/386505/3834
# Reducing Wasted Food at Home
# https://www.epa.gov/recycle/reducing-wasted-food-home
# Raspberry Pi 4 launch site runs on a Pi 4 cluster
# https://arstechnica.com/information-technology/2019/06/the-raspberry-pi-4-launch-site-runs-on-a-pi-4-cluster/
# AnimEigo: The AnimEigo Titling System
# https://www.animeigo.com/about/secret-history-animeigo
# My $3.3M Mistake (2009)
# https://sivers.org/mistake
# How to pick a random number from 1-10
# https://torvaney.github.io/projects/human-rng
# Pigeon – Crowdsourced transit app for New Yorkers
# https://pigeon.area120.com/
# MarIQ – Q-Learning Neural Network for Mario Kart [video]
# https://www.youtube.com/watch?v=Tnu4O_xEmVk
# Electric cars: New vehicles to emit noise to aid safety
# https://www.bbc.co.uk/news/business-48815968
# With a single wiretap, police collected 9.2M text messages
# https://techcrunch.com/2019/06/29/wiretap-prosecutors-texas/
# Why humans run the world, Yuval Noah Harari (2015) [video]
# https://www.youtube.com/watch?v=nzj7Wg4DAbs
# CS Unplugged: Teaching material for CS using cards, string and crayons
# https://www.csunplugged.org/en/
# The Cyberutopian (2014)
# http://magazine.williams.edu/2014/fall/feature/the-cyberutopian/
# Staging That Scene from ‘Eyes Wide Shut’
# https://www.vulture.com/2019/06/eyes-wide-shut-orgy-scene-oral-history.html
# Apple releases iOS 13 macOS Catalina public betas
# https://beta.apple.com/sp/betaprogram/
# Baoshang Bank collapse threatens China's economy and may trigger central bank
# https://mobile.abc.net.au/news/2019-06-28/baoshang-bank-collapse-hits-lending-threatens-chinese-economy/11252022
# SKS Keyserver Network Under Attack
# https://gist.github.com/rjhansen/67ab921ffb4084c865b3618d6955275f
# I’ve Picked My Job over My Kids
# https://www.nytimes.com/2019/06/29/opinion/sunday/ive-picked-my-job-over-my-kids.html
# GNU Linear Programming Kit
# https://en.wikibooks.org/wiki/GLPK
# India is now producing the world’s cheapest solar power
# https://www.weforum.org/agenda/2019/06/india-is-now-producing-the-world-s-cheapest-solar-power/
# Researchers propose ways to avoid blackouts with renewable energy (2018)
# https://news.stanford.edu/2018/02/08/avoiding-blackouts-100-renewable-energy/
# Building an intelligent journal in Clojure, Part 1
# https://matthiasnehlsen.com/blog/2019/02/28/meins-intro/
# Network Transparency with Wayland
# https://mstoeckl.com/notes/gsoc/blog.html
# Matias RGB Backlit Wired Aluminum Keyboard for Mac
# https://matias.ca/aluminum/mac-rgb/
# High-Pressure Processing of Food
# https://www.slideshare.net/zgoutham/high-pressure-processing-of-food
# NASA plans to launch a spacecraft to Titan
# https://www.theatlantic.com/science/archive/2019/06/titan-saturn-nasa-dragonfly/592882/
# Gilbert U-238 Atomic Energy Lab Toy (1950-1951)
# https://www.orau.org/PTP/collection/atomictoys/GilbertU238Lab.htm
# Mindfulness is associated with reduced levels of procrastination
# https://solvingprocrastination.com/procrastination-study-mindfulness/
# Infinite loop in macOS Night Shift in the summer near the Arctic Circle
# https://twitter.com/AustinJ/status/1144655793612107778
# Let's Build a Simple Interpreter. Part 14: Nested Scopes (2017)
# https://ruslanspivak.com/lsbasi-part14/
# Interns’ Job Prospects Constrained by Noncompete Agreements
# https://www.wsj.com/articles/interns-job-prospects-constrained-by-noncompete-agreements-11561800600?mod=rsswn
# How Disney built and programmed an animatronic president (2014)
# https://arstechnica.com/the-multiverse/2014/06/how-disney-built-and-programmed-an-animatronic-president/
# A Library Handles a Rare and Deadly Book of Wallpaper Samples (2018)
# https://www.atlasobscura.com/articles/shadows-from-the-walls-of-death-book
# NetBSD on the last G4 Mac mini and making the kernel power failure proof
# http://tenfourfox.blogspot.com/2019/06/and-now-for-something-completely.html
# The FreeDOS Project turns 25
# https://www.freedos.org/
# Making Protein Using Air, Water, Electricity, and Microbes
# https://www.theguardian.com/environment/2019/jun/29/plan-to-sell-50m-meals-electricity-water-air-solar-foods
# Conficker: The worm that nearly ate the internet
# https://www.nytimes.com/2019/06/29/opinion/sunday/conficker-worm-ukraine.html
# Fuchsia Developers Website
# https://fuchsia.dev/
# Toshiba and WD NAND Production Hit by Power Outage: 6 Exabytes Lost
# https://www.anandtech.com/show/14596/toshiba-western-digital-nand-production-partially-halted-by-power-outage
# Reset C by GE Light Bulbs [video]
# https://www.youtube.com/watch?v=1BB6wj6RyKo
# The side of Paul Allen I wish more people knew about
# https://www.gatesnotes.com/About-Bill-Gates/Forbes-Philanthropy-Summit-honors-Paul-Allen
# Jony Ive to form independent design company with Apple as client
# https://www.apple.com/newsroom/2019/06/jony-ive-to-form-independent-design-company-with-apple-as-client/
# Riichi Mahjong Strategy Books
# https://dainachiba.github.io/RiichiBooks/
# Digital Video Game Firsts – Michigan Pool (1954)
# https://www.masswerk.at/nowgobang/2019/michigan-pool
# Google’s new reCAPTCHA has a dark side
# https://www.fastcompany.com/90369697/googles-new-recaptcha-has-a-dark-side
# New Property of Light Discovered
# https://phys.org/news/2019-06-property.html
# Demystifying Containers 101: A Deep Dive into Container Technology for Beginners
# https://www.freecodecamp.org/news/demystifying-containers-101-a-deep-dive-into-container-technology-for-beginners-d7b60d8511c1/
# Demystifying Databases: Correctness Anomalies Under Serializable Isolation
# https://fauna.com/blog/demystifying-database-systems-correctness-anomalies-under-serializable-isolation
# Europe has had five 500-year summers in 15 years
# https://www.nationalgeographic.com/environment/2019/06/europe-has-had-five-500-year-summers-in-15-years/
# Windows 3.x looks for 3 occurrences of “CON” 59 bytes apart
# https://books.google.com/books?id=LIyy_CtozLcC&pg=PA360&lpg=PA360&focus=viewport
# Evernote Blows Up the ‘Fail Fast’ Gospel
# https://www.nytimes.com/2019/06/28/business/evernote-what-happened.html
# Capehart Communications Collection – For Sale
# https://telemuseum.info/
# What Is the Human Microbiome, Exactly?
# http://nautil.us/blog/what-is-the-human-microbiome-exactly
# Sneaky deals are keeping cheaper generic medicines off the market
# https://www.latimes.com/business/lazarus/la-fi-lazarus-generic-drugs-pay-for-delay-20190627-story.html#nws=mcnewsletter
# The International Space Station is growing mould, inside and outside
# https://www.cbc.ca/news/technology/international-space-station-mould-1.5193970
# America’s Monopoly Crisis Hits the Military
# https://www.theamericanconservative.com/articles/americas-monopoly-crisis-hits-the-military/
# Open Letter from the OpenID Foundation to Apple Regarding Sign in with Apple
# https://openid.net/2019/06/27/open-letter-from-the-openid-foundation-to-apple-regarding-sign-in-with-apple/
# Researchers model how octopus arms make decisions
# https://news.agu.org/press-release/researchers-model-how-octopus-arms-make-decisions/
# NSA Improperly Collected U.S. Phone Records a Second Time
# https://www.usatoday.com/story/news/nation/2019/06/26/nsa-improperly-obtained-phone-call-data-after-saying-issues-were-fixed/1568914001/
# One-on-one meetings are underrated, whereas group meetings waste time (2017)
# http://www.smashcompany.com/business/one-on-one-meetings-are-underrated-whereas-group-meetings-waste-time
# Reinventing Firefox for Android
# https://blog.mozilla.org/futurereleases/2019/06/27/reinventing-firefox-for-android-a-preview/
# Friends Like These: On Thoreau and Emerson
# https://lareviewofbooks.org/article/friends-like-these-on-thoreau-and-emerson/
# Magical, Mystical JavaScript Transducers
# https://jrsinclair.com/articles/2019/magical-mystical-js-transducers/
# The Evolution of Lisp (1993) [pdf]
# https://www.dreamsongs.com/Files/HOPL2-Uncut.pdf
# Schools are using unproven surveillance technology to monitor students
# https://features.propublica.org/aggression-detector/the-unproven-invasive-surveillance-technology-schools-are-using-to-monitor-students/
# Jami – FOSS, Distributed Instant Messenger
# https://jami.net/
# Red Hat Expecting X.org to “Go into Hard Maintenance Mode Fairly Quickly”
# https://www.phoronix.com/scan.php?page=news_item&px=X.Org-Maintenance-Mode-Quickly
# Awk by Example
# https://developer.ibm.com/tutorials/l-awk1/
# Equiano, a subsea cable from Portugal to South Africa
# https://cloud.google.com/blog/products/infrastructure/introducing-equiano-a-subsea-cable-from-portugal-to-south-africa
# Berlin Brandenburg: The airport with half a million faults
# https://www.bbc.co.uk/news/world-48527308
# Announcing Startup School 2019
# https://blog.ycombinator.com/announcing-startup-school-2019/
# Subway Got Too Big – Franchisees Paid a Price
# https://www.nytimes.com/2019/06/28/business/subway-franchisees.html
# Show HN: A platform to encourage friendly competition within your office
# https://www.breadsticks.org/
# The little legacy code that could: a fable of software ownership
# https://circleci.com/blog/the-little-legacy-code-that-could-a-fable-of-software-ownership/
# Show HN: A music delivery service built around the WebAudio API
# https://ampl.fi/?ref=1
# One In Five Employees Is Highly Engaged and at Risk of Burnout (2018)
# https://hbr.org/2018/02/1-in-5-highly-engaged-employees-is-at-risk-of-burnout
# Freeing My Phone from Google
# https://www.hexaquo.at/posts/2019/06/29/Freeing+my+phone+from+Google
# Without a GUI: How to Live Entirely in a Terminal
# https://www.linuxjournal.com/content/without-gui-how-live-entirely-terminal
# Jaguar Land Rover to build electric cars at UK factory
# https://www.reuters.com/article/us-jaguarlandrover-britain/jaguar-land-rover-to-build-electric-cars-at-uk-factory-report-idUSKCN1TU0YB
# Programming Patterns I Like
# https://www.johnstewart.dev/five-programming-patterns-i-like
# Finland’s weekly news show in Latin cancelled after run of 30 years
# https://www.theguardian.com/world/2019/jun/28/finland-latin-news-radio-bulletin-nuntii-latini-cancelled-30-years
# Fighting Theranos Charges, Holmes Blames Advocacy Journalism
# https://www.bloomberg.com/news/articles/2019-06-28/fighting-theranos-charges-holmes-blames-advocacy-journalism
# Atari Centipede’s Hidden Code Trap
# https://arcadeblogger.com/2019/06/29/atari-centipedes-hidden-code-trap/
# Qwant Maps: open-source and privacy-preserving map
# https://betterweb.qwant.com/qwant-maps-a-open-and-privacy-focused-map/
# The Internet Archive’s 2019 Artists in Residency Exhibition
# https://blog.archive.org/2019/06/22/the-internet-archives-2019-artist-in-residency-exhibition/
# Galactic Algorithms (2010)
# https://rjlipton.wordpress.com/2010/10/23/galactic-algorithms/
# Early Digital Research CP/M Source Code
# https://www.computerhistory.org/atchm/early-digital-research-cpm-source-code/
# Terence Tao's Raw Notes After His Princeton Comprehensive Exams (1999)
# https://web.math.princeton.edu/generals/tao_terence
# I used ML to find public domain Krazy Kat comics in newspaper archives
# https://joel.franusic.com/krazy_kat/about/
# It's Time to Tax Us More
# https://medium.com/@letterforawealthtax/an-open-letter-to-the-2020-presidential-candidates-its-time-to-tax-us-more-6eb3a548b2fe
# A 30th anniversary note to Prince of Persia fans
# https://www.jordanmechner.com/prince-of-persia-30th-anniversary/
# NASA’s restored Apollo Mission Control is a slice of ’60s life, frozen in amber
# https://arstechnica.com/science/2019/06/behind-the-scenes-at-nasas-newly-restored-historic-apollo-mission-control/
# Hans Zimmer designed the sound for BMW’s futuristic concept car
# https://www.theverge.com/2019/6/29/19914287/bmw-hans-zimmer-design-bmw-vision-m-next-sound-profile-blade-runner-cyberpunk-3d-print
# A Model Estonian Soldier Who Spied for Russia
# https://www.theatlantic.com/international/archive/2019/06/estonia-russia-deniss-metsavas-spy/592417/
# Snap! 5 is here
# https://snap.berkeley.edu/site/blog
# Ive’s Legacy, the Post-Ive Apple
# https://stratechery.com/2019/jony-ive-leaves-apple-ives-legacy-the-post-ive-apple/
# Not Enough Delilahs
# https://www.lrb.co.uk/v41/n13/andrew-ohagan/not-enough-delilahs
# They Come for Us at Night: China's Vanishing Muslims
# https://www.youtube.com/watch?v=v7AYyUqrMuQ
# In fighting cancer, look to what big animals do
# https://www.economist.com/science-and-technology/2019/06/29/in-fighting-cancer-look-to-what-other-animals-do
# Welcome to the Old Internet Again
# http://theoldnet.com/
# Brave Improves Its Ad-Blocker Performance with New Engine in Rust
# https://brave.com/improved-ad-blocker-performance/
# Some extinct species of crocodile were herbivores
# https://phys.org/news/2019-06-extinct-crocs-vegetarians.html
# How AMD Gave China the ‘Keys to the Kingdom’
# https://www.wsj.com/articles/u-s-tried-to-stop-china-acquiring-world-class-chips-china-got-them-anyway-11561646798?mod=rsswn
# Cracking the puzzle of automated low-cost malaria diagnosis
# https://twitter.com/PrakashLab/status/1144453714637230083
# Apple Moves Mac Pro Production to China
# https://www.wsj.com/articles/apple-moves-mac-pro-production-to-china-11561728769?mod=rsswn
# Regular Expression Matching Can Be Simple and Fast (2007)
# https://swtch.com/~rsc/regexp/regexp1.html
# Fast.ai Part 2: Deep Learning from the Foundations
# https://course.fast.ai/part2
# Computer Graphics Final Project 1989 Detailed
# https://techwithdave.davevw.com/2019/06/computer-graphics-final-project-1989.html
# Sperm-Donor Siblings: A Family Portrait
# https://www.nytimes.com/interactive/2019/06/26/magazine/sperm-donor-siblings.html
# Gmail’s API lockdown will kill some third-party app access, starting July 15
# https://arstechnica.com/?p=1528361
# One Casualty of the Palm Oil Industry: An Orangutan Mother, Shot 74 Times
# https://www.nytimes.com/2019/06/29/world/asia/orangutan-indonesia-palm-oil.html
# Most Unit Testing Is Waste (2014) [pdf]
# https://rbcs-us.com/documents/Why-Most-Unit-Testing-is-Waste.pdf
# A Rooftop Device That Can Make Solar Power and Cool Buildings
# https://news.stanford.edu/press-releases/2018/11/08/new-device-can-cy-cool-buildings/
# Attempts to Censor AntiPolygraph.org
# https://antipolygraph.org/blog/2019/06/28/pseudoscientist-dr-charles-humble-attempts-to-censor-antipolygraph-org/
# Everything everywhere is securities fraud
# https://www.bloomberg.com/opinion/articles/2019-06-26/everything-everywhere-is-securities-fraud
# Gallery Owner Arrested After Placing Giant Drug Spoon Sculpture at Purdue Pharma
# https://www.courant.com/news/connecticut/hc-news-stamford-opioids-spoon-sculpture-0623-story.html
# The Simple Genius of Checklists
# https://blog.nuclino.com/the-simple-genius-of-checklists-from-b-17-to-the-apollo-missions
# Machine learning systems are stuck in a rut
# https://blog.acolyer.org/2019/06/28/machine-learning-systems-are-stuck-in-a-rut/
# Mozilla Server Side TLS – Recommended Configurations
# https://wiki.mozilla.org/Security/Server_Side_TLS#Recommended_configurations
# What I Learned Co-Founding Dribbble
# http://simplebits.com/2019/06/25/dribbble.html
# I’ve spent five years writing a JavaScript framework
# https://medium.com/@jcormont/ive-spent-5-years-writing-a-javascript-framework-on-my-own-af1201f4075c
# Learning to Love the AI Bubble
# https://sloanreview.mit.edu/article/learning-to-love-the-ai-bubble/
# Western intelligence hacked Yandex to spy on accounts
# https://www.reuters.com/article/us-usa-cyber-yandex-exclusive-idUSKCN1TS2SX
# First AI universe sim is fast and accurate – its creators don't know how
# https://phys.org/news/2019-06-ai-universe-sim-fast-accurateand.html
# Former Equifax CIO sentenced for insider trading
# https://www.justice.gov/usao-ndga/pr/former-equifax-employee-sentenced-insider-trading
# Cruzbit: A simple decentralized peer-to-peer ledger
# https://medium.com/@asdvxgxasjab/cruzbit-a-simple-decentralized-peer-to-peer-ledger-2944495b6129
# Boeing falsified records for 787 jet that developed a fuel leak
# https://www.cbc.ca/news/business/boeing-air-canada-jet-fuel-leak-1.5193550
# I’m Leaving IBM
# https://www.schneier.com/blog/archives/2019/06/im_leaving_ibm.html
# Using AWK and R to parse 25TB
# https://livefreeordichotomize.com/2019/06/04/using_awk_and_r_to_parse_25tb/
# Libra is targeted at developing countries
# https://www.iafrikan.com/2019/06/27/facebooks-libra-may-be-quite-attractive-in-developing-countries/
# It’s Time for Some Queueing Theory
# https://kottke.org/19/01/its-time-for-some-queueing-theory
# Drivers followed a Google Maps detour and ended up stuck in an empty field
# https://edition-m.cnn.com/2019/06/26/us/google-maps-detour-colorado-trnd/index.html
# The Slow Climb of Postgres and the Value of Persistence
# https://thenewstack.io/the-slow-climb-of-postgres-and-the-value-of-persistence/
# Magic 3D Clock
# http://www.technoblogy.com/show?2KGV
# Show HN: Prototype and Style Web Apps with HTML Snapshots
# https://pinegrow.com/snapshots
# How Chinese Food Fueled the Rise of California Punk
# https://www.topic.com/how-chinese-food-fueled-the-rise-of-california-punk
# Why U.S. Cities Aren’t Using More Electric Buses
# https://www.citylab.com/transportation/2019/06/electric-bus-china-grid-ev-charging-infrastructure-battery/591655/
# AMD Responds to WSJ ‘Keys to the Kingdom’ Story
# https://www.amd.com/en/corporate/wsj-response
# “The books will stop working.”
# https://twitter.com/rdonoghue/status/1144011630197522432
# Millions of Chinese expats using VPNs to get back inside China's Great Firewall
# https://www.abc.net.au/news/2019-06-29/chinese-overseas-using-vpns-to-get-inside-great-firewall-china/11255612
# OS X/Linker: New Mac malware attempts zero-day Gatekeeper bypass
# https://www.intego.com/mac-security-blog/osx-linker-new-mac-malware-attempts-zero-day-gatekeeper-bypass/
# What’s Up with Ancient Greek Epitaphs
# https://www.theparisreview.org/blog/2019/06/27/whats-up-with-ancient-greek-epitaphs/
# SpaceX faces daunting challenges if it’s going to win the internet space race
# https://www.latimes.com/business/la-fi-spacex-starlink-constellation-20190628-story.html
# Experimental Slack-to-Keybase team importer
# https://keybase.io/slack-importer
# Navy Got 'UFO' Patent Granted by Warning of Similar Chinese Tech Advances
# https://www.thedrive.com/the-war-zone/28729/docs-show-navy-got-ufo-patent-granted-by-warning-of-similar-chinese-tech-advances
# Animating Doodles with Autoencoders and Synthetic Data (2018)
# https://rajatvd.github.io/Animating-Doodles-With-Autoencoders/
# Uber/Lyft drivers say they were misled into petitioning against workers rights
# https://www.vox.com/recode/2019/6/27/18759387/uber-lyft-drivers-misled-companies-political-campaig
# Why switch is better than if-else
# https://mortoray.com/2019/06/29/why-switch-is-better-than-if-else/
# The Popularity of the 4.7″ iPhone
# https://david-smith.org/blog/2019/06/24/the-popularity-of-the-4-dot-7-inch-iphone/
# Apple Hires Key Chip Designer From ARM as Own Efforts Ramp Up
# https://www.bloomberg.com/news/articles/2019-06-26/apple-hires-key-chip-designer-from-arm-as-own-efforts-ramp-up
# Defining Public Interest on Twitter
# https://blog.twitter.com/en_us/topics/company/2019/publicinterest.html
# Was OS/2 a viable alternative for daily DOS and Windows tasks?
# https://retrocomputing.stackexchange.com/questions/5907/was-os-2-a-viable-alternative-for-daily-dos-and-windows-tasks
# How to speak Silicon Valley: 53 essential tech-bro terms explained
# https://www.theguardian.com/us-news/2019/jun/26/how-to-speak-silicon-valley-decoding-tech-bros-from-microdosing-to-privacy
# The varieties of material existence (2018)
# http://cognitivemedium.com/vme
# China's biggest startups ditch Oracle and IBM for home-made tech
# https://www.scmp.com/tech/enterprises/article/3015931/chinas-biggest-start-ups-ditch-oracle-and-ibm-home-made-tech-us
# CUDA Grep
# https://www.cs.cmu.edu/afs/cs/academic/class/15418-s12/www/competition/bkase.github.com/CUDA-grep/finalreport.html
# Documenting Climate Change by Air, Land and Sea
# https://www.nytimes.com/2019/05/14/lens/climate-change-josh-haner-air-land-and-sea.html
# Getting to grips with rocket science
# https://spectator.us/getting-grips-rocket-science-apollo/
# FreeDOS's Linux Roots
# https://www.linuxjournal.com/content/freedoss-linux-roots
# $499 AMD Ryzen 9 3900X Almost as Fast as $2000 Intel Core I9-9980XE
# https://www.techquila.co.in/amd-ryzen-9-3900x-intel-core-i9/
# How to Understand the Universe When You’re Stuck Inside of It
# https://www.quantamagazine.org/were-stuck-inside-the-universe-lee-smolin-has-an-idea-for-how-to-study-it-anyway-20190627/
# The Programmers' Stone (2014)
# https://www.datapacrat.com/Opinion/Reciprocality/r0/index.html
# Temperatures in France cross 45°C threshold for first time since records began
# https://www.euronews.com/2019/06/28/france-records-highest-temperature-since-records-began-at-44-3-celsius-meteo-france
# What's the deal with square traces on PCBs?
# https://hackaday.com/2019/06/26/whats-the-deal-with-square-traces-on-pcbs/
# Yogurt may help to lower pre-cancerous bowel growth risk in men
# https://gut.bmj.com/content/early/2019/05/22/gutjnl-2019-318374
# EC2 Instance Connect
# https://aws.amazon.com/about-aws/whats-new/2019/06/introducing-amazon-ec2-instance-connect/
# Pentagon has a laser that can identify people at a distance by their heartbeat
# https://www.technologyreview.com/s/613891/the-pentagon-has-a-laser-that-can-identify-people-from-a-distanceby-their-heartbeat/
# Why are the username and password on two different pages?
# https://www.twilio.com/blog/why-username-and-password-on-two-different-pages
# AWS Glue/Athena/Redshift outage
# https://status.aws.amazon.com/
# Microsoft, Keep Your Hands Off My Keyboard
# https://yngve.vivaldi.net/2019/06/20/microsoft-keep-your-hands-off-my-keyboard/
# Trump Allows U.S. Sales to Huawei as Trade Talks Resume
# https://www.wsj.com/articles/trump-says-he-is-set-to-discuss-huawei-with-xi-11561769726?mod=rsswn
# Show HN: RemoteJS – Remote Browser Debugging
# https://remotejs.com/
# How China Really Sees the Trade War
# https://www.foreignaffairs.com/articles/china/2019-06-27/how-china-really-sees-trade-war
# FAA Finds New Risk on 737 Max, Orders Boeing to Make Changes
# https://www.bloomberg.com/news/articles/2019-06-26/faa-finds-new-risk-on-737-max-and-orders-boeing-to-make-changes
# A New Wave of Bad Ads Is Hijacking Even Top-Tier Websites (2018)
# https://www.fastcompany.com/40516897/a-new-wave-of-bad-ads-is-hijacking-even-top-tier-websites
# We’re Updating Our Terms of Service to Better Explain How Facebook Works
# https://newsroom.fb.com/news/2019/06/updating-our-terms/
# A Fashion Photographer Who Duped Drug Lords and the DEA
# https://www.bloomberg.com/news/features/2019-06-27/the-fashion-photographer-who-duped-drug-cartels-and-the-dea
# Shocking evidence shows people in vegetative states may be conscious
# https://www.newscientist.com/article/mg24232360-800-shocking-evidence-shows-people-in-vegetative-states-may-be-conscious/
# Tourist's lucky guess cracks safe code on first try
# https://www.bbc.co.uk/news/world-us-canada-48477081
# Public-Interest Technology Resources
# https://public-interest-tech.com/
# IT professionals should work in a mainframe environment at some point (2015)
# https://www.planetmainframe.com/2015/12/every-it-professional-should-work-in-a-mainframe-environment-at-some-point/
# US Navy's Railgun Now Undergoing Tests in New Mexico
# https://www.thedrive.com/the-war-zone/28669/navys-railgun-now-undergoing-tests-in-new-mexico-could-deploy-on-ship-in-northwest
# Why Cutting Costs Is Expensive How $9/Hour Engineers Cost Boeing Billions
# https://medium.com/javascript-scene/why-cutting-costs-is-expensive-how-9-hour-software-engineers-cost-boeing-billions-b76dbe571957
# Boeing's 737 Max software outsourced to lower-paid engineers
# https://www.bloomberg.com/news/articles/2019-06-28/boeing-s-737-max-software-outsourced-to-9-an-hour-engineers
# Computer Science vs. Computing Science (1999)
# http://www.cs.utexas.edu/users/EWD/transcriptions/EWD12xx/EWD1284.html
# The affordable housing crisis, explained
# https://www.curbed.com/2019/5/15/18617763/affordable-housing-policy-rent-real-estate-apartment
# The explosions, reenactments, and animals that made Vauxhall Gardens a hot spot
# https://www.laphamsquarterly.org/roundtable/may-we-entertain-you
# Cypherpunks Tapping Bitcoin via Ham Radio
# https://www.wired.com/story/cypherpunks-bitcoin-ham-radio/
# Sikh drivers are transforming U.S. trucking
# https://www.latimes.com/nation/la-na-col1-sikh-truckers-20190627-htmlstory.html
# Free Sex Pot Bust Rap – Introduction to Noun Talk
# https://billwadge.wordpress.com/2019/06/28/free-sex-pot-bust-rap/
# Building Lyft’s Marketing Automation Platform
# https://eng.lyft.com/lyft-marketing-automation-b43b7b7537cc
# A Well-Regulated Apocalypse: The Code of Emergency Federal Regulations (2016)
# https://jasonlefkowitz.net/2016/11/regulating-the-apocalypse-inside-the-code-of-emergency-federal-regulations/
# Secure ShellFish – SSH and SFTP Storage for iOS
# https://apps.apple.com/us/app/secure-shellfish/id1336634154?ls=1
# Durable Design (2017)
# http://exple.tive.org/blarg/2017/09/13/durable-design/
# BMW Lets Slip That Its Electric Vehicles Can’t Compete with Tesla’s
# https://cleantechnica.com/2019/06/28/bmw-lets-slip-that-its-electric-vehicles-cant-compete-with-teslas/
# The Art and Science of Software Estimation – Part 2: The Nature of Software
# https://cousine.me/posts/the-art-and-science-of-software-estimation-part-2/
# Snowden's talk at Bitcoin 2019 conference [video]
# https://www.youtube.com/watch?v=PVN13ad3UUk
# Windows Terminal Preview Available
# https://www.microsoft.com/en-us/p/windows-terminal-preview/9n0dx20hk701
# US military is a bigger polluter than as many as 140 countries
# https://theconversation.com/us-military-is-a-bigger-polluter-than-as-many-as-140-countries-shrinking-this-war-machine-is-a-must-119269
# Forever young: The hidden age discrimination scandal in the tech industry
# https://www.telegraph.co.uk/technology/2019/06/29/forever-young-hidden-age-discrimination-scandal-tech-industry/
# Superhuman
# https://a16z.com/2019/06/27/superhuman/
# RPM Packages Explained
# https://fedoramagazine.org/rpm-packages-explained/
# On Jony Ive Leaving Apple
# https://daringfireball.net/2019/06/jony_ive_leaves_apple
# Type inference has usability problems
# http://austinhenley.com/blog/typeinference.html
# Thom Yorke’s beautiful new nightmare
# https://www.theatlantic.com/entertainment/archive/2019/06/thom-yorke-anima-album-review-terrifying-beauty/592750/
# India reportedly wants to build its own WhatsApp for government communications
# https://techcrunch.com/2019/06/26/india-government-inhouse-chat-app-whatsapp/
# NPM 6.9.1 is broken due to .git folder in published tarball
# https://npm.community/t/npm-6-9-1-is-broken-due-to-git-folder-in-published-tarball/8454/2
# Cisco Leap Frogs H.264 Video Collaboration with Real-Time AV1 Codec
# https://blogs.cisco.com/collaboration/cisco-leap-frogs-h-264-video-collaboration-with-real-time-av1-codec
# Why is Stack Overflow trying to start audio?
# https://meta.stackoverflow.com/questions/386487/why-is-stack-overflow-trying-to-start-audio
# DOJ's Boeing investigation expands to 787 Dreamliner
# https://edition-m.cnn.com/2019/06/28/politics/boeing-investigation-expands-787-dreamliner/index.html
# Why are pedestrian deaths increasing in the US?
# http://cityobservatory.org/why-are-us-drivers-killing-so-many-pedestrians/
# Show HN: Fiuti.com – A tool to create Google Ads campaigns 20X faster
# https://fiuti.com/app/campaign-builder
# VLC media player 3.0.6 and earlier: Read buffer overflow and double free
# https://www.videolan.org/security/sa1901.html
# 'Today, Hong Kong; Tomorrow, Taiwan:' Resistance to China Spreads
# https://asia.nikkei.com/Spotlight/Cover-Story/Today-Hong-Kong-tomorrow-Taiwan-Resistance-to-China-spreads
# SaaS Blocks – Building a SaaS Product in 2019
# https://saasblocks.io/
# Luis Alvarez, Champion of 9/11 Responders, Dies at 53
# https://www.nytimes.com/2019/06/29/obituaries/luis-alvarez-dead.html
# Ravens parallel great apes in flexible planning for tool-use, bartering (2017)
# https://science.sciencemag.org/content/357/6347/202.full
# Hacker News TV – made up from the best HN videos
# https://www.producthunt.com/posts/hacker-news-tv
# Reverse Engineering Cyclic Redundancy Codes
# https://hackaday.com/2019/06/27/reverse-engineering-cyclic-redundancy-codes/
# The battle against gender segregation in French suburbs (2016)
# https://www.france24.com/en/video/20161219-france-battle-against-gender-segregation-french-suburbs
# Leaked Ryzen 5 3600 Benchmark Better Single-Thread Performance Than Core I9-9900
# https://www.tomshardware.com/news/amd-ryzen-5-3600-benchmark-beats-core-i9-9900k,39768.html
# Passenger threatened with court for using screenshot of e-ticket
# https://www.theguardian.com/money/2019/jun/29/passenger-threatened-with-court-for-using-screenshot-of-e-ticket
# Regulators Have Doubts About Facebook Cryptocurrency, and So Do Its Partners
# https://www.nytimes.com/2019/06/25/technology/facebook-libra-cryptocurrency.html
# Radioactive water at Fukushima Daiichi: What should be done? (2018)
# https://blog.safecast.org/2018/06/part-1-radioactive-water-at-fukushima-daiichi-what-should-be-done/
# Eve Online is in chaos after an unprecedented alien invasion
# https://www.pcgamer.com/eve-online-is-in-chaos-after-an-unprecedented-alien-invasion/
# Some of America’s Top Chicken Purveyors Are Under Investigation for Price Fixing
# https://www.eater.com/2019/6/26/18759596/chicken-price-fixing-investigation-perdue-tyson-sanderson-farms
# I Retired at 34 with $3M
# https://www.cnbc.com/2019/06/24/i-retired-at-34-with-3-million-here-are-the-downsides-of-early-retirement-that-no-one-tells-you.html
# Protest in Madrid as conservatives suspend ban on most polluting cars
# https://www.reuters.com/article/us-spain-environment-protests/protest-in-madrid-as-conservatives-suspend-ban-on-most-polluting-cars-idUSKCN1TU0VS
# Publishers Not Making Much Money from Apple News+
# https://www.macrumors.com/2019/06/28/publishers-apple-news-plus-revenue/
# History Will Not Be Kind to Jony Ive
# https://www.vice.com/en_us/article/ywyjmw/history-will-not-be-kind-to-jony-ive
# Apple to Manufacture New Mac Pro Computer in China Instead of U.S.
# https://www.nytimes.com/2019/06/28/technology/apple-mac-pro-china.html
# Bat-Killing Wind Turbines Outfitted with Systems to Stop Carnage
# https://news.duke-energy.com/releases/duke-energy-renewables-to-use-new-technology-to-help-protect-bats-at-its-wind-sites
# Thin yet Repairable Devices: HP Proves They Exist
# https://www.ifixit.com/News/hp-makes-the-modern-repairable-devices-you-might-have-forgotten-existed
# The NBA Wants You to Bet on Games That Never Happened
# https://www.bloomberg.com/news/articles/2019-06-19/nba-s-newest-gambling-product-betting-on-games-that-don-t-exist
# How We Realized Putting Radium in Everything Was Not the Answer
# https://www.theatlantic.com/health/archive/2013/03/how-we-realized-putting-radium-in-everything-was-not-the-answer/273780/
# Facebook's Advertising Attribution Con
# https://jafferaliblog.wordpress.com/2019/06/27/facebook-con-will-it-lead-to-its-collapse/
# Anxiety, Depression, and Decision Making: A Computational Perspective [pdf]
# https://www.gwern.net/docs/rl/2019-bishop.pdf
# JSON Resume – 5th Birthday and New Features
# https://jsonresume.org/blog/5th-birthday-new-features
# Another Hacked Florida City Pays a Ransom, This Time for $460k
# https://www.nytimes.com/2019/06/27/us/lake-city-florida-ransom-cyberattack.html
# U.S. may outlaw messaging encryption used by WhatsApp, iMessage and others
# https://www.forbes.com/sites/zakdoffman/2019/06/29/u-s-may-outlaw-uncrackable-end-to-end-encrypted-messaging-report-claims/#432b030e6c87
# Trade War Has Damaged U.S. Chip Industry
# https://www.nytimes.com/2019/06/27/technology/trade-war-chipmakers.html
# Jony Ive’s Fragmented Legacy: Unreliable, Unrepairable, Beautiful Gadgets
# https://www.ifixit.com/News/jony-ives-fragmented-legacy-unreliable-unrepairable-beautiful-gadgets
# San Francisco school board votes to destroy murals by Victor Arnautoff
# https://www.nytimes.com/2019/06/28/opinion/sunday/san-francisco-life-of-washington-murals.html
# Show HN: Space Bandits, space startup database and interviews
# https://www.spacebandits.io
# How Bad Are Things? (2015)
# https://slatestarcodex.com/2015/12/24/how-bad-are-things/
# Centuries-Old Sea Captain Diaries Are Confirming Modern Climate Science
# https://www.vice.com/en_us/article/mb8nga/centuries-old-sea-captain-diaries-are-confirming-modern-climate-science
# Plan to sell 50m meals made from electricity, water and air
# https://www.theguardian.com/environment/2019/jun/29/plan-to-sell-50m-meals-electricity-water-air-solar-foods
# Writing an OS in Rust: Heap Allocation
# https://os.phil-opp.com/heap-allocation/
# Have Smartphones Destroyed a Generation? (2017)
# https://www.theatlantic.com/magazine/archive/2017/09/has-the-smartphone-destroyed-a-generation/534198/
# Robots 'to replace up to 20M factory jobs' by 2030
# https://www.bbc.co.uk/news/business-48760799
# Nokia Slams Huawei After 'Potential Backdoors' Found in 55% of Its Devices
# https://www.forbes.com/sites/zakdoffman/2019/06/28/nokia-slams-huawei-after-potential-backdoors-found-in-55-of-its-devices/#5c9e0d7f4119
# Japan's pitch free data flows faces uphill G20 battle amid 'splinternet' fears
# https://www.japantimes.co.jp/news/2019/06/27/business/tech/japans-pitch-free-data-flows-trust-faces-uphill-battle-g20-amid-splinternet-fears/
# How Two Firefox Zero Days Led to Two macOS Backdoors
# https://www.sentinelone.com/blog/how-two-firefox-zero-days-led-to-two-macos-backdoors/
# VS Code settings you should customize
# https://dev.to/thegeoffstevens/vs-code-settings-you-should-customize-5e75
# Spike in Autism May Be Linked to Preservative in Processed Foods, Study Suggests
# https://www.forbes.com/sites/robertglatter/2019/06/28/spike-in-autism-may-be-linked-to-preservative-in-processed-foods-study-suggests/
# Andrej Karpathy – Multi-Task Learning in the Wilderness
# https://slideslive.com/38916929/multitask-learning-in-the-wilderness
# House votes to block Ajit Pai’s plan to kill San Francisco broadband law
# https://arstechnica.com/tech-policy/2019/06/house-votes-to-block-ajit-pais-plan-to-kill-san-francisco-broadband-law/
# NASA’s restored Apollo Mission Control is a slice of 60s life, frozen in amber
# https://arstechnica.com/science/2019/06/behind-the-scenes-at-nasas-newly-restored-historic-apollo-mission-control/
# Randomized SQL Testing in CockroachDB
# https://www.cockroachlabs.com/blog/sqlsmith-randomized-sql-testing/
# It turns out planes are even worse for the climate than we thought
# https://www.newscientist.com/article/2207886-it-turns-out-planes-are-even-worse-for-the-climate-than-we-thought/
# GrubHub is buying up thousands of restaurant web addresses
# https://newfoodeconomy.org/grubhub-domain-purchases-thousands-shadow-sites/
# PostgreSQL Stored Procs Finally Supported in a Distributed SQL Database
# https://blog.yugabyte.com/yugabyte-db-engineering-update-june-27-2019/
# YouTube Lets Users Override Recommendations After Criticism
# https://www.bloomberg.com/news/articles/2019-06-26/youtube-lets-users-override-recommendations-after-criticism
# Air Conditioning Is the World's Next Big Threat
# https://www.bloomberg.com/opinion/articles/2019-06-28/air-conditioning-is-the-world-s-next-big-threat
# Adapting TriforceAFL for NetBSD
# http://blog.netbsd.org/tnf/entry/adapting_triforceafl_for_netbsd_part
# America colonisation ‘cooled Earth's climate’
# https://www.bbc.com/news/science-environment-47063973
# How to Format a String in C++
# https://inversepalindrome.com/blog/how-to-format-a-string-in-cpp
# The Strange Politics of Facial Recognition
# https://www.theatlantic.com/technology/archive/2019/06/democrats-and-republicans-passing-soft-regulations/592558/
# The Joel Test: 12 Steps to Better Code
# https://www.joelonsoftware.com/2000/08/09/the-joel-test-12-steps-to-better-code/
# Xkcd 2169: Predictive Models
# https://xkcd.com/2169/
# Twitter clarifies special rules for tweets by world leaders like Trump
# https://arstechnica.com/tech-policy/2019/06/trump-tweets-will-get-warning-labels-if-they-break-rules-twitter-says/
# AWS S3 leaks data from Fortune 100 firms
# https://www.zdnet.com/article/aws-s3-server-leaks-data-from-fortune-100-companies-ford-netflix-td-bank/
# The Internet Pinball Database
# https://www.ipdb.org/
# 2001: Linux is cancer, says Microsoft. 2019: ah, can we join Linux mailing list?
# https://www.theregister.co.uk/2019/06/27/microsoft_linux_distro_list/
# Dijkstra Archive (1930-2002)
# http://www.cs.utexas.edu/users/EWD/
# Mozilla's new mobile Firefox browser pushes speed, privacy on Android phones
# https://www.cnet.com/news/mozillas-new-mobile-firefox-browser-pushes-speed-privacy-android-phones/
# Wikipedia community reacts to an editor being temporarily banned
# https://www.buzzfeednews.com/article/josephbernstein/wikipedia-ban-editor-culture-war
# NASA will send new lander to Titan
# https://www.nasa.gov/press-release/nasa-selects-flying-mission-to-study-titan-for-origins-signs-of-life/
# Elizabeth Holmes to Face Trial Next Year on Fraud Charges
# https://www.wsj.com/articles/theranos-founder-elizabeth-holmes-to-face-trial-next-year-on-fraud-charges-11561754180?mod=rsswn
# Mount Everest has become an “open toilet”
# https://www.foxnews.com/world/mount-everest-has-human-waste-problem-official-says
# Grubhub is using fake websites to upcharge commission fees from real businesses
# https://www.theverge.com/2019/6/28/19154220/grubhub-seamless-fake-restaurant-domain-names-commission-fees
# EU and Mercosur reach agreement on trade
# http://europa.eu/rapid/press-release_IP-19-3396_en.htm
# Update on Steam, Ubuntu, and 32-bit support
# https://steamcommunity.com/app/221410/discussions/0/1640915206447625383/
# How to Speak Silicon Valley
# https://www.theguardian.com/us-news/2019/jun/26/how-to-speak-silicon-valley-decoding-tech-bros-from-microdosing-to-privacy
# Solid Design Principles: The Guide to Becoming Better Developers
# https://adevait.com/software/solid-design-principles-the-guide-to-becoming-better-developers
# Americans Greatly Overestimate U.S. Gay Population
# https://news.gallup.com/poll/259571/americans-greatly-overestimate-gay-population.aspx
# Intel about AMDs Competitive Profile
# https://www.reddit.com/r/Amd/comments/c5nb01/amd_competitive_profile_where_we_go_toetotoe_why/
# How to speak Silicon Valley: 53 essential tech-bro terms explained
# https://www.theguardian.com/us-news/2019/jun/26/how-to-speak-silicon-valley-decoding-tech-bros-from-microdosing-to-privacy
# How a trivial cell phone hack is ruining lives
# https://www.engadget.com/2019/06/28/cell-phone-hack-is-ruining-lives-identity-theft/
# The demise of Microsoft's eBook store; everything will 'stop working' with DRM
# https://www.androidpolice.com/2019/06/28/microsoft-ebooks-drm-end/
# Slack – Degraded service affecting multiple features
# https://status.slack.com/2019-06/9f63d8e30ee85f46
# Just 100 companies responsible for 71% of global emissions, study says
# https://www.theguardian.com/sustainable-business/2017/jul/10/100-fossil-fuel-companies-investors-responsible-71-global-emissions-cdp-study-climate-change
# Chinese Scientists Guilty of ‘Researching as Asian’ in Trump’s America
# https://www.scmp.com/magazines/post-magazine/long-reads/article/3016267/chinese-scientists-guilty-researching-while
# NASA to Announce New Mission Live at 4pm ET
# https://www.nytimes.com/2019/06/27/science/nasa-titan-dragonfly-caesar.html
# About 70% of SaaS Unicorns Are New Versions of Existing Categories of Software
# https://www.saastr.com/about-70-of-saas-unicorns-are-new-versions-of-existing-categories-of-software/
# No Drips, No Drops: A City of 10M Is Running Out of Water
# https://www.npr.org/sections/goatsandsoda/2019/06/25/734534821/no-drips-no-drops-a-city-of-10-million-is-running-out-of-water
# Bank of America will not do business with companies that run detention centers
# https://www.cnn.com/2019/06/26/business/bank-of-america-private-detention/
# Streaming TV is about to get expensive – here's why
# https://www.theguardian.com/tv-and-radio/2019/jun/27/streaming-tv-is-about-to-get-very-expensive-heres-why
# Rust: A Language for the Next 40 Years [video]
# https://www.youtube.com/watch?v=A3AdN7U24iU
# AMD Working on a Hybrid Ray Tracing Technology (Hardware X Software)
# https://www.techquila.co.in/amd-hybrid-ray-tracing/
# Generating Delay-Tolerant Networks as Solution to Bitcoin-Like Google Index
# https://twitter.com/marknadal/status/1144870642556125184
# Guardian told it was target of Saudi hacking unit after Khashoggi killing
# https://www.theguardian.com/world/2019/jun/19/guardian-told-it-was-target-of-saudi-hacking-unit-after-khashoggi-killing
# Burl, a game you play in the URL
# http://burl.link/#dfbuggfffffdudduu
# The painful and lonely death of Laika, the space dog
# https://medium.com/@joelerego/the-painful-and-lonely-death-of-laika-the-space-dog-c7cd965d5adf
# 'Shocking' Fake Takeaway Sold on Uber Eats
# https://www.bbc.co.uk/news/av/uk-48762211/shocking-fake-takeaway-sold-on-uber-eats
# 2001: Linux is cancer, says Ms. 2019: can we join the official Linux-distros ML?
# https://www.theregister.co.uk/2019/06/27/microsoft_linux_distro_list/
# MIT: Building on Julia programming to open up AI to novices
# https://www.zdnet.com/article/mit-were-building-on-julia-programming-language-to-open-up-ai-coding-to-novices/
# Silicon Valley's UFO Hunters
# https://www.vice.com/en_us/article/597ebn/meet-silicon-valleys-ufo-hunters
# How to Fix the Tech Hiring
# https://medium.com/@fagnerbrack/how-to-fix-the-tech-hiring-f56ae8192d8c
# The Six-Year Struggle to Regain Ownership of the ‘This Is Fine’ Dog
# https://www.vulture.com/2019/06/this-is-fine-dog-meme-comic-kc-green-interview.html
# Would You Pay $30 a Month to Check Your Email?
# https://www.nytimes.com/2019/06/27/technology/superhuman-email.html
# New AI deepfake app creates nude images of women in seconds
# https://www.theverge.com/2019/6/27/18760896/deepfake-nude-ai-app-women-deepnude-non-consensual-pornography
# Boeing Falsified Documents Leading to Fuel Leak on an Air Canada Dreamliner
# https://ca.news.yahoo.com/falsified-boeing-documents-led-fuel-025934488.html
# Show HN: Log-with-statusbar: NPM log package where the last line doesn't scroll
# https://www.npmjs.com/package/log-with-statusbar
# Mark Zuckerberg Is Rethinking Deepfakes
# https://www.theatlantic.com/technology/archive/2019/06/zuckerberg-very-good-case-deepfakes-are-completely-different-from-misinformation/592681/
# Second world war bomb explodes after three-quarters of a century
# https://www.newscientist.com/article/2207515-second-world-war-bomb-explodes-after-three-quarters-of-a-century/
# Kris Kristofferson's Lyme Disease Misdiagnosed as Alzheimer's (2016)
# https://www.cbsnews.com/news/kris-kristofferson-misdiagnosed-alzheimers-has-lyme-disease/
# Ajit Pai's Silence on Phone Tracking Abuse Is Eroding Faith in His Competence
# https://gizmodo.com/ajit-pais-silence-on-phone-location-abuse-is-further-er-1835921741
# Biostars – Bioinformatics Q&A Site
# https://www.biostars.org/
# An Open Letter to Google and Apple: Stop Hindering Iranian Entrepreneurs
# https://techcrunch.com/2019/06/18/an-open-letter-to-google-and-apple-stop-hindering-iranian-entrepreneurs/
# A heroin addiction fueled a former engineer’s bank robbery spree
# https://www.bloomberg.com/features/2019-anthony-hathaway-hooked-on-bank-robbing/
# Firefox Will Give You a Fake Browsing History to Fool Advertisers
# https://www.vice.com/en_us/article/43j8qm/firefox-will-give-you-a-fake-browsing-history-to-fool-advertisers
# Asteroid named after Brian Eno by astronomers
# https://www.cnn.com/2019/06/27/world/brian-eno-asteroid-named-after-him-trnd/index.html
# BMW Says European Customers Aren't Demanding EVs
# https://www.forbes.com/sites/michaeltaylor/2019/06/27/bmw-says-european-customers-arent-demanding-evs/#193c3e6b141b
# New Property of Light Discovered
# https://m.phys.org/news/2019-06-property.html
# Power failure in Japan cuts WD and Toshiba flash production
# https://www.theregister.co.uk/2019/06/28/western_digital_power_cut_flash_supply/
# Cocaine Is Back. Blame Technology for It
# https://finance.yahoo.com/news/cocaine-back-blame-technology-061644997.html
# Average salaries, favourite languages: A look at Functional Programming in 2019
# https://functional.works-hub.com/learn/the-state-of-functional-programming-2019-8f02b
# The Lambda Calculus for Fun and Factorials (Ron Garret, 2015)
# https://www.youtube.com/watch?v=8qC1iZN5ozw
# DeepNude was killed off by its creator
# https://www.cnn.com/2019/06/27/tech/deepnude-naked-women-ai/index.html
# Why ICOs Are Broken
# https://medium.com/@jimmysong/why-icos-are-broken-3f918bd5b3fb
# We Need to Decentralize Publishing Again
# https://medium.com/cardstack/we-need-to-decentralize-publishing-again-7828be8c067b
# Discovery of a 'holy grail' with the invention of universal computer memory
# https://www.sciencedaily.com/releases/2019/06/190620100015.htm
# GeckoView in 2019
# https://hacks.mozilla.org/2019/06/geckoview-in-2019/
# I felt the fear of abduction by China in Hong Kong
# https://www.theguardian.com/commentisfree/2019/jun/28/china-abuction-hong-kong-beijing-g20-ma-jian
# A fork of Stewart Butterfield's iconic saddle memo
# https://medium.com/@ericwchung/we-dont-sell-group-chats-here-ad9eb8906440
# Apollo 11 tapes bought for $218 may sell for millions after nearly being lost
# https://www.theguardian.com/science/2019/jun/28/apollo-11-tapes-moon-landing-sale-value-nearly-lost
# New flaw discovered on Boeing 737 Max, sources say
# https://edition.cnn.com/2019/06/26/politics/boeing-737-max-flaw/index.html
# White House weighs encryption crackdown
# https://www.politico.com/story/2019/06/27/trump-officials-weigh-encryption-crackdown-1385306?cid=apn
# Yes, it’s worth arguing with science deniers
# https://www.niemanlab.org/2019/06/yes-its-worth-arguing-with-science-deniers-and-here-are-some-techniques-you-can-use/
# Fed up with being in the slow queue? That’s why queues are being ‘designed out’
# https://theconversation.com/fed-up-with-always-being-in-the-slow-queue-thats-why-queues-are-being-designed-out-92514
# You don't need Kubernetes on your laptop
# https://medium.com/garden-io/you-dont-need-kubernetes-on-your-laptop-37653cbb28c9
# Business Is Not About Your Product, It’s About Your Customers
# https://medium.com/better-marketing/your-business-is-not-about-your-product-its-about-your-customers-db60d7c1877b
# Simplify Your Code with Rocket Science: C++20’s Spaceship Operator
# https://devblogs.microsoft.com/cppblog/simplify-your-code-with-rocket-science-c20s-spaceship-operator/
# Google blocks abortion ads in Australia
# https://www.abc.net.au/news/2019-06-27/australian-abortion-clinic-ads-gone-from-google/11250158
# Facebook Starting Salaries: What Tech Professionals Can Expect
# https://insights.dice.com/2019/06/27/facebook-starting-salaries-tech/
# The Staggering Cost of Training SOTA AI Models
# https://medium.com/syncedreview/the-staggering-cost-of-training-sota-ai-models-e329e80fa82
# New York City declares climate emergency, first major US city to do so
# https://www.cnn.com/2019/06/27/us/new-york-city-declared-climate-emergency-trnd/index.html
# GitHub is running extra copies, indexed by Google
# https://rubygems.pkg.github.com/NixOS
# Trump officials weigh encryption crackdown
# https://www.politico.com/story/2019/06/27/trump-officials-weigh-encryption-crackdown-1385306
# Growing evidence suggests Parkinson's disease starts in gut
# https://www.theguardian.com/society/2019/jun/26/growing-evidence-suggests-parkinsons-disease-starts-in-gut
# Non-compete clause
# https://en.wikipedia.org/wiki/Non-compete_clause
# Dying Bookstore to NYC: Just Treat Us Like You Treated Amazon
# https://www.fastcompany.com/90369805/struggling-book-culture-to-nyc-just-treat-us-like-amazon
# Battle lines being drawn: A map of YIMBY-NIMBY skirmishes in Bay Area
# https://www.mercurynews.com/2019/06/26/battle-lines-being-drawn-a-map-of-yimby-nimby-skirmishes-in-bay-area/
# Being a Female Programmer: How Is It for You?
# https://dev.to/ilonacodes/being-a-female-programmer-how-is-it-for-you-i7d
# I Am Developing Solely on a No-Brand Android 5.1 Tablet
# http://tbf-rnd.life/blog/2019/06/27/why-i-am-developing-solely-on-a-no-brand-android-5-1-tablet/
# Huawei employees reportedly worked on Chinese military research projects
# https://www.cnet.com/news/huawei-employees-reportedly-worked-on-chinese-military-research-projects/
# Russia’s Citizens Can’t Escape Their Largest Tech Company
# https://www.bloomberg.com/news/articles/2019-06-25/how-russia-s-citizens-can-t-escape-their-largest-tech-company
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-a4c23742edc8> in <module>
#       5     if d['type'] == 'story':
#       6         if 'text' not in d.keys():
# ----> 7             if all([w not in d['url'] for w in url_words]):
#       8                 if all([w not in d['url'] for w in url_words]):
#       9                     if all([w not in d['title'] for w in title_words]):
#
# <ipython-input-3-a4c23742edc8> in <listcomp>(.0)
#       5     if d['type'] == 'story':
#       6         if 'text' not in d.keys():
# ----> 7             if all([w not in d['url'] for w in url_words]):
#       8                 if all([w not in d['url'] for w in url_words]):
#       9                     if all([w not in d['title'] for w in title_words]):
#
# KeyError: 'url'

# %% [markdown]
# ## Using a trained model

# %% [markdown]
# First, we need to train a model, and I don't feel like labelling a few thousand HN submissions `tech` / `not tech`, so let's use a famous dataset: [20 newsgroups](https://www.cs.umb.edu/~smimarog/textmining/datasets/)

# %%
TEXT_DATA_DIR = '20_newsgroup'
texts, label_text = [], []
for name in sorted(os.listdir(TEXT_DATA_DIR)):
    path = os.path.join(TEXT_DATA_DIR, name)
    if os.path.isdir(path):
        for fname in sorted(os.listdir(path)):
            if fname.isdigit():
                fpath = os.path.join(path, fname)
                with open(fpath, encoding='latin-1') as f:
                    t = f.read()
                    i = t.find('\n\n')  # skip header in file (starts with two newlines.)
                    if i > 0:
                        t = t[i:]
                    texts.append(t)
                label_text.append(name)
print(f'Found {len(texts)} texts.')
# Out:
# Found 19997 texts.

# %%
train = pd.DataFrame({'sent':texts, 'label': label_text})
train.head()
# Out:
#                                                 sent        label
# 0  \n\nArchive-name: atheism/resources\nAlt-athei...  alt.atheism
# 1  \n\nArchive-name: atheism/introduction\nAlt-at...  alt.atheism
# 2  \n\nIn article <65974@mimsy.umd.edu>\nmangoe@c...  alt.atheism
# 3  \n\ndmn@kepler.unh.edu (...until kings become ...  alt.atheism
# 4  \n\nIn article <N4HY.93Apr5120934@harder.ccr-p...  alt.atheism

# %% [markdown]
# We have our labelled data. Now we label anything 'techy' as such.

# %%
tech = ['comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 
        'comp.windows.x', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space']
train['is_tech'] = 0
train.loc[train.label.isin(tech), 'is_tech'] = 1

# %% [markdown]
# Building the model:

# %%
import string
import en_core_web_sm
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
punctuations = string.punctuation
nlp = en_core_web_sm.load()
parser = English()

def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in STOP_WORDS and word not in punctuations ]
    return mytokens

class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        return [clean_text(text) for text in X]
    def fit(self, X, y=None, **fit_params):
        return self
    def get_params(self, deep=True):
        return {}

def clean_text(text):
    return text.strip().lower()

X = train['sent']
ylabels = train['is_tech']
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3)

bow_vector = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)
classifier = LogisticRegression(solver='liblinear')
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', bow_vector),
                 ('classifier', classifier)])
pipe.fit(X_train,y_train)
predicted = pipe.predict(X_test)

print("Logistic Regression Accuracy:",metrics.accuracy_score(y_test, predicted))
print("Logistic Regression Precision:",metrics.precision_score(y_test, predicted))
print("Logistic Regression Recall:",metrics.recall_score(y_test, predicted))
# Out:
# Logistic Regression Accuracy: 0.9458333333333333
# Logistic Regression Precision: 0.9319391634980989
# Logistic Regression Recall: 0.9437812860993454

# %% [markdown]
# Wow, pretty good results on that tests dataset. Now we run it on our model:

# %%
df = pd.DataFrame({'text':[d['title'] for d in data], 'is_tech': pipe.predict(pd.Series(titles))})
df.head(20)
# Out:
#                                                  text  is_tech
# 0                                        Planet Moons        1
# 1                             The German Tank Problem        0
# 2          Why factoring may be easier than you think        1
# 3                           Graphs and Geometry [pdf]        1
# 4                      The Cost of JavaScript in 2019        0
# 5       Show HN: Web pages stored entirely in the URL        0
# 6   Open Letter to the Wikimedia Foundation Board ...        0
# 7   China pressured London police to arrest Tianan...        0
# 8   Vintage video game cartridges with built-in mo...        0
# 9              Live coding a vi for CP/M from scratch        1
# 10      Xlambda: A window manager extensible in Guile        1
# 11  The Energy Cost of Electric and Human-Powered ...        0
# 12  New home page makes it seem like Stack Overflo...        0
# 13  Tell HN: Social media strike proposed for July...        0
# 14                       Reducing Wasted Food at Home        0
# 15  Raspberry Pi 4 launch site runs on a Pi 4 cluster        1
# 16              AnimEigo: The AnimEigo Titling System        0
# 17                            My $3.3M Mistake (2009)        0
# 18              Lazydocker: a terminal GUI for Docker        1
# 19              How to pick a random number from 1-10        1

# %% [markdown]
# Hmm, not the best. Needs some work!
